# %%
#data wrangling
import pandas as pd

#datetime
import datetime as dt

#format number
pd.options.display.float_format = '{:,.2f}'.format

# %%
# load sheet Transactions trong file KPMG và in ra 5 dòng đầu tiên
transactions = pd.read_excel('KPMG.xlsx', sheet_name = 'Transactions')
transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25          0.00
# 1               2           3         3120       2017-05-21          1.00
# 2               3          37          402       2017-10-16          0.00
# 3               4          88         3135       2017-08-31          0.00
# 4               5          78          787       2017-10-01          1.00
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
# in ra info bảng
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
# describe default
transactions.describe()
# Out:
#        transaction_id  product_id  customer_id  online_order  list_price  \
# count       20,000.00   20,000.00    20,000.00     19,640.00   20,000.00
# mean        10,000.50       45.36     1,738.25          0.50    1,107.83
# std          5,773.65       30.75     1,011.95          0.50      582.83
# min              1.00        0.00         1.00          0.00       12.01
# 25%          5,000.75       18.00       857.75          0.00      575.27
# 50%         10,000.50       44.00     1,736.00          1.00    1,163.89
# 75%         15,000.25       72.00     2,613.00          1.00    1,635.30
# max         20,000.00      100.00     5,034.00          1.00    2,091.47
#
#        standard_cost  product_first_sold_date
# count      19,803.00                19,803.00
# mean          556.05                38,199.78
# std           405.96                 2,875.20
# min             7.21                33,259.00
# 25%           215.14                35,667.00
# ...

# %%
# describe các biến object
transactions.describe(include=[object])
# Out:
#        order_status  brand product_line product_class product_size
# count         20000  19803        19803         19803        19803
# unique            2      6            4             3            3
# top        Approved  Solex     Standard        medium       medium
# freq          19821   4253        14176         13826        12990

# %%
#describe all
transactions.describe(include = 'all')
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_23136/2061221955.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   transactions.describe(include = 'all')
#         transaction_id  product_id  customer_id     transaction_date  \
# count        20,000.00   20,000.00    20,000.00                20000
# unique             NaN         NaN          NaN                  364
# top                NaN         NaN          NaN  2017-02-14 00:00:00
# freq               NaN         NaN          NaN                   82
# first              NaN         NaN          NaN  2017-01-01 00:00:00
# last               NaN         NaN          NaN  2017-12-30 00:00:00
# mean         10,000.50       45.36     1,738.25                  NaN
# ...

# %%
# count số dòng bị null ở mỗi cột
transactions.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %% [markdown]
# # 1. Data Correction

# %% [markdown]
# ## 1.1 Drop NA

# %%
# tạo bảng df_dropna_all bằng cách loại bỏ tất cả giá trị null trong bảng và in ra info
df_dropna_all = transactions.dropna()
df_dropna_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19445 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           19445 non-null  int64
#  1   product_id               19445 non-null  int64
#  2   customer_id              19445 non-null  int64
#  3   transaction_date         19445 non-null  datetime64[ns]
#  4   online_order             19445 non-null  float64
#  5   order_status             19445 non-null  object
#  6   brand                    19445 non-null  object
#  7   product_line             19445 non-null  object
#  8   product_class            19445 non-null  object
#  9   product_size             19445 non-null  object
#  10  list_price               19445 non-null  float64
#  11  standard_cost            19445 non-null  float64
#  12  product_first_sold_date  19445 non-null  float64
# ...

# %%
# tạo bảng df_dropna_online_order bằng cách loại bỏ giá trị null trong cột online_order và in ra info
df_dropna_online_order = transactions.dropna(subset = ['online_order'])
df_dropna_online_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19640 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           19640 non-null  int64
#  1   product_id               19640 non-null  int64
#  2   customer_id              19640 non-null  int64
#  3   transaction_date         19640 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             19640 non-null  object
#  6   brand                    19445 non-null  object
#  7   product_line             19445 non-null  object
#  8   product_class            19445 non-null  object
#  9   product_size             19445 non-null  object
#  10  list_price               19640 non-null  float64
#  11  standard_cost            19445 non-null  float64
#  12  product_first_sold_date  19445 non-null  float64
# ...

# %% [markdown]
# ## 1.2 Fill NA

# %%
# fill tất cả NA bằng 0, lưu vào bảng df_fillna_0 và in ra info
df_fillna_0 = transactions.fillna(value = 0)
df_fillna_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             20000 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    20000 non-null  object
#  7   product_line             20000 non-null  object
#  8   product_class            20000 non-null  object
#  9   product_size             20000 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            20000 non-null  float64
#  12  product_first_sold_date  20000 non-null  float64
# ...

# %%
# fill NA bằng ffill, lưu vào bảng df_fillna_ffill và in ra info
df_fillna_ffill = transactions.fillna(method = 'ffill') 
df_fillna_ffill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             20000 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    20000 non-null  object
#  7   product_line             20000 non-null  object
#  8   product_class            20000 non-null  object
#  9   product_size             20000 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            20000 non-null  float64
#  12  product_first_sold_date  20000 non-null  float64
# ...

# %%
# fill NA bằng bfill, lưu vào bảng df_fillna_bfill và in ra info
df_fillna_bfill = transactions.fillna(method = 'bfill')
df_fillna_bfill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             20000 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    20000 non-null  object
#  7   product_line             20000 non-null  object
#  8   product_class            20000 non-null  object
#  9   product_size             20000 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            20000 non-null  float64
#  12  product_first_sold_date  20000 non-null  float64
# ...

# %% [markdown]
# ## 1.3. Assess Categorial Data

# %%
# load sheet Demographic và hiển thị top head
demographic = pd.read_excel('KPMG.xlsx', sheet_name = 'CustomerDemographic')
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_23136/2002255289.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   demographic = pd.read_excel('KPMG.xlsx', sheet_name = 'CustomerDemographic')

# %%
# in ra info bảng 
demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
# describe các giá trị object
demographic.describe(include = [object])
# Out:
#        first_name last_name  gender                             job_title  \
# count        4000      3875    4000                                  3494
# unique       3139      3725       6                                   195
# top           Max  Pristnor  Female  Business Systems Development Analyst
# freq            5         3    2037                                    45
#
#        job_industry_category wealth_segment deceased_indicator  default  \
# count                   3344           4000               4000     3698
# unique                     9              3                  2       90
# top            Manufacturing  Mass Customer                  N      100
# freq                     799           2000               3998      113
#
#        owns_car
# count      4000
# unique        2
# top         Yes
# freq       2024

# %%
# Remove all NA row
demographic.dropna()
demographic = demographic.dropna()

# %%
# In ra các giá trị unique của cột gender
demographic.gender.unique()
# Out:
# array(['F', 'Male', 'Female', 'Femal'], dtype=object)

# %%
# Quy chuẩn cột Gender về 2 nhóm Male và Female, Unisex và in ra giá trị unique mới
demographic['gender'] = demographic['gender'].replace(['M','F','U','Femal'],['Male','Female','Unisex','Female'])
demographic.gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# Tính tuổi của mỗi khách hàng và lưu vào cột "Age" và in ra min age, max age
import datetime
demographic['DOB'] = pd.to_datetime(demographic['DOB'])
year = pd.DatetimeIndex(demographic['DOB']).year
current_year = datetime.datetime.now().year
demographic['Age'] = current_year - year

print(demographic['Age'].max())
print(demographic['Age'].min())
# Out:
# 91
# 20

# %%
demographic[demographic['Age'] == 179]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, default, owns_car, tenure, Age]
# Index: []

# %%
# phân nhóm khách hàng dưới 35 tuổi là nhóm "Young", Từ 36 - 55 là "Middle", trên 55 là Older
# lưu vào cột "Age_Group" bằng cách sử dụng hàm cut
demographic['Age_Group'] = pd.cut(demographic['Age']
                                  , bins = [0,36,55,1000]
                                  , labels = ['Young', 'Middle', 'Older']
                                  , right = True)
demographic.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 8            9       Mala       Lind  Female
# 9           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 8                                   97 1973-03-10
# 9                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 8  Business Systems Development Analyst           Argiculture
# 9               Senior Quality Engineer    Financial Services
#
# ...

# %% [markdown]
# # 2. Data Completeness

# %%
#join data sale vs demographic và in ra những trường hợp missing trong demographic
sale_demographic = transactions.merge(demographic, how = 'left', on = 'customer_id')
sale_demographic[sale_demographic['first_name'].isnull()]
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 4                   5          78          787       2017-10-01          1.00
# 7                   8          15         2459       2017-07-15          0.00
# 10                 11           5         1986       2017-01-17          0.00
# 16                 17          79         2426       2017-04-03          0.00
# 24                 25          89         2822       2017-06-11          0.00
# ...               ...         ...          ...              ...           ...
# 19988           19989           0          714       2017-04-27          1.00
# 19991           19992          11         1374       2017-09-14          0.00
# 19992           19993          13            5       2017-04-28          0.00
# 19993           19994          77         2618       2017-12-23          0.00
# 19998           19999           6         2764       2017-07-03          0.00
#
# ...

# %% [markdown]
# # 3. Data Aggregation

# %%
# tính tổng khách hàng bằng hàm nunique
sale_demographic['customer_id'].nunique(dropna = True)
# Out:
# 3494

# %%
# Tính số khách khách hàng mỗi tháng
# hint 1: tạo collum year_month bằng hàm dt.strftime
# hint 2: group by year_month và nunique
sale_demographic['year_month'] = pd.to_datetime(sale_demographic['transaction_date']).dt.to_period('M')
customer_per_month = sale_demographic.groupby(by = 'year_month')['customer_id'].nunique()
customer_per_month
# Out:
# year_month
# 2017-01    1354
# 2017-02    1286
# 2017-03    1317
# 2017-04    1310
# 2017-05    1310
# 2017-06    1266
# 2017-07    1354
# 2017-08    1372
# 2017-09    1263
# 2017-10    1414
# 2017-11    1319
# 2017-12    1322
# Freq: M, Name: customer_id, dtype: int64

# %%
# Tính Gross magin của mỗi tháng. Gross magin = list_price - standard_cost
# hint 1: tạo collum Gross_Margin
# hint 2: group by year_month và sử dụng hàm agg
sale_demographic['Gross_Margin'] = sale_demographic['list_price'] - sale_demographic["standard_cost"]
gross_margin_per_month = sale_demographic.groupby(by = 'year_month')["Gross_Margin"].sum()
gross_margin_per_month
# Out:
# year_month
# 2017-01   929,487.74
# 2017-02   870,819.06
# 2017-03   879,243.40
# 2017-04   904,691.31
# 2017-05   913,742.61
# 2017-06   859,571.55
# 2017-07   938,619.29
# 2017-08   970,452.52
# 2017-09   862,290.49
# 2017-10   984,973.46
# 2017-11   924,938.46
# 2017-12   891,454.07
# Freq: M, Name: Gross_Margin, dtype: float64

# %%
# Tính số lượng order và doanh thu group by online_order và order_status 
# hint 1: group by online_order, order_status và sử dụng hàm agg
total_order_gross = sale_demographic.groupby(by = ['online_order','order_status'])['online_order','Gross_Margin'].sum()
total_order_gross
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_23136/718971586.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   total_order_gross = sale_demographic.groupby(by = ['online_order','order_status'])['online_order','Gross_Margin'].sum()
#                            online_order  Gross_Margin
# online_order order_status
# 0.00         Approved              0.00  5,344,968.90
#              Cancelled             0.00     42,930.74
# 1.00         Approved          9,732.00  5,287,679.96
#              Cancelled            97.00     53,236.73

# %% [markdown]
# # 4. Data Visualization

# %%
# Sử dụng seaborn và vẽ ra 5 loại chart khác nhau (column, line, box,...) với đầy đủ tên chart, tên các trục và chú thích.
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x = 'gender', data = sale_demographic, palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.boxplot(x = 'gender', y = 'Age', data = sale_demographic)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Age'>

# %%
gross_margin_per_month = pd.DataFrame(gross_margin_per_month)
gross_margin_per_month = gross_margin_per_month.reset_index()
gross_margin_per_month
# Out:
#    year_month  Gross_Margin
# 0     2017-01    929,487.74
# 1     2017-02    870,819.06
# 2     2017-03    879,243.40
# 3     2017-04    904,691.31
# 4     2017-05    913,742.61
# 5     2017-06    859,571.55
# 6     2017-07    938,619.29
# 7     2017-08    970,452.52
# 8     2017-09    862,290.49
# 9     2017-10    984,973.46
# 10    2017-11    924,938.46
# 11    2017-12    891,454.07

# %%
gross_margin_per_month.plot(x = 'year_month', y = 'Gross_Margin', kind = 'line', title = 'Gross Margin per month')
# Out:
# <AxesSubplot:title={'center':'Gross Margin per month'}, xlabel='year_month'>

# %%
customer_per_month = pd.DataFrame(customer_per_month).rename(columns={'customer_id' : 'Total_customer'})
customer_per_month = customer_per_month.reset_index()
customer_per_month
# Out:
#    year_month  Total_customer
# 0     2017-01            1354
# 1     2017-02            1286
# 2     2017-03            1317
# 3     2017-04            1310
# 4     2017-05            1310
# 5     2017-06            1266
# 6     2017-07            1354
# 7     2017-08            1372
# 8     2017-09            1263
# 9     2017-10            1414
# 10    2017-11            1319
# 11    2017-12            1322

# %%
customer_per_month.plot(x= 'year_month', y= 'Total_customer', kind= 'bar', title= 'Total customer per month')
plt.xlabel('Month')
plt.ylabel('Total customer')
# Out:
# Text(0, 0.5, 'Total customer')

# %%
sns.catplot(x = 'product_line', data = sale_demographic, kind = 'count')
